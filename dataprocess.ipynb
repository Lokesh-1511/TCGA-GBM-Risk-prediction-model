# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokesh-1511/TCGA-GBM-Risk-prediction-model/blob/main/dataprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas tqdm
